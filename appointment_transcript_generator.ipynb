# %% [markdown]
# <a href="https://colab.research.google.com/github/klemenp950/ElektronskaTajnica/blob/main/appointment_transcript_generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Medical Appointment Phone Call Transcript Generator
#
# This notebook generates synthetic transcriptions of phone conversations between patients calling to schedule medical appointments and doctor's office assistants.
#
# **Conversation Structure:**
# - **spk_0**: Doctor's office assistant
# - **spk_1**: Patient calling to schedule appointment
#
# **Typical Flow:**
# 1. Assistant greets and asks how they can help
# 2. Patient describes their issue/reason for visit
# 3. Patient provides their name
# 4. Discussion of preferred date and time
# 5. Patient mentions their doctor's name
# 6. Confirmation and closing
#
# Uses **Microsoft Phi-4** to generate realistic conversational transcripts.

# %%
# === CONFIGURATION ===
NUM_TRANSCRIPTS = 100  # Change this number to generate more or fewer transcripts
OUTPUT_DIR = "/data/generated_transcripts"  # Directory to save the generated transcripts
MODEL_NAME = "microsoft/phi-4"  # Phi-4 model from Hugging Face

# If you have the model downloaded locally, set the path here:
# MODEL_NAME = "/path/to/local/phi-4"

print(f"Configuration:")
print(f"  Number of transcripts to generate: {NUM_TRANSCRIPTS}")
print(f"  Output directory: {OUTPUT_DIR}")
print(f"  Model: {MODEL_NAME}")
# Out:
# Configuration:
#   Number of transcripts to generate: 100
#   Output directory: /data/generated_transcripts
#   Model: microsoft/phi-4

# %%
# Install required packages (uncomment if needed)
# !pip install transformers accelerate torch
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.1)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.11.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.10.5)

# %%
import os
import json
from pathlib import Path
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch
import random

print("Importing libraries complete.")
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
# Out:
# Importing libraries complete.
# PyTorch version: 2.8.0+cu126
# CUDA available: True

# %%
# Load Microsoft Phi-4 model
print(f"Loading model: {MODEL_NAME}...")
print("This may take a few minutes on first run.")

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME, trust_remote_code=True)
model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    trust_remote_code=True,
    torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32,
    device_map="auto" if torch.cuda.is_available() else None
)

# Set padding token if not set
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

print("Model loaded successfully!")
print(f"Device: {next(model.parameters()).device}")
# Out:
# Loading model: microsoft/phi-4...
# This may take a few minutes on first run.
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/95.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/802 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# model-00001-of-00006.safetensors:   0%|          | 0.00/4.93G [00:00<?, ?B/s]
# model-00006-of-00006.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# model-00002-of-00006.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00003-of-00006.safetensors:   0%|          | 0.00/4.90G [00:00<?, ?B/s]
# model-00004-of-00006.safetensors:   0%|          | 0.00/4.77G [00:00<?, ?B/s]
# model-00005-of-00006.safetensors:   0%|          | 0.00/4.77G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/6 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/156 [00:00<?, ?B/s]
# Model loaded successfully!
# Device: cuda:0

# %%
# Prompt templates for generating diverse conversations
PROMPT_TEMPLATE = """Generate a realistic phone conversation transcript between a doctor's office assistant (spk_0) and a patient (spk_1) calling to schedule an appointment.
The conversation that you must generate must include reason for visiting doctors office, patient's name, preferred date/time, and doctor's name. Mark doctors office speaker with spk_0 and patient speaker with spk_1. Make sure that customer doesn't introduce himself first. First introduce yourself, then ask patient about their condition, than their name than doctor and then suggested date and time. Do not suggest doctors name, let patient tell themself who their doctor is. do not suggest time, always ask patient when they have time to visit. Do not check for time, just take suggestion from patient and tell tham that you wrote it down.



Format each line as:
spk_0: [assistant's dialogue]
spk_1: [patient's dialogue]

The conversation should include:
1. Greeting from the assistant
2. Patient describes their medical issue or reason for visit: {issue}
3. Patient provides their full name: {name}
4. Discussion of preferred appointment date and time: {datetime}
5. Patient mentions their doctor: Dr. {doctor}
6. Confirmation and polite closing

Make it natural, focus only on facts, no repeating conditions or names no sympathising with patient

Transcript:
"""

# Sample data for variety
MEDICAL_ISSUES = [
    "persistent headaches for the past week",
    "follow-up for blood pressure monitoring",
    "annual physical examination",
    "persistent cough and congestion",
    "knee pain after exercising",
    "skin rash that won't go away",
    "discuss recent lab results",
    "flu-like symptoms",
    "medication refill and consultation",
    "back pain management",
    "allergic reaction symptoms",
    "routine diabetes check-up",
    "migraine consultation",
    "sprained ankle evaluation",
    "digestive issues"
]

PATIENT_NAMES = [
    "Sarah Johnson",
    "Michael Chen",
    "Emily Rodriguez",
    "David Thompson",
    "Jessica Williams",
    "James Martinez",
    "Amanda Davis",
    "Robert Anderson",
    "Lisa Brown",
    "Christopher Lee",
    "Jennifer Taylor",
    "Daniel Kim",
    "Michelle White",
    "Kevin Patel",
    "Ashley Garcia",
    "Brian Adams",
    "Nicole Miller",
    "Brandon Scott",
    "Stephanie King",
    "Eric Green",
    "Olivia Wilson",
    "Ethan Moore",
    "Sophia Hall",
    "Noah Baker",
    "Ava Wright",
    "Liam Adams",
    "Isabella Carter",
    "Mason Evans",
    "Mia Roberts",
    "Alexander Phillips"
]

APPOINTMENT_TIMES = [
    "tomorrow at 2 PM",
    "next Monday morning around 10 AM",
    "this Friday afternoon, maybe 3 or 4 PM",
    "next week, preferably Wednesday at 11 AM",
    "Thursday at 9:30 AM if possible",
    "early next week, around 8 AM",
    "next Tuesday at 1 PM",
    "sometime this week, afternoon would be best",
    "Monday or Tuesday morning, before 10",
    "end of this week, Friday around noon",
    "next Wednesday at 2:30 PM",
    "early morning on Thursday, 8:30 AM",
    "next Monday afternoon at 4 PM",
    "this Thursday at 10:30 AM",
    "next Friday morning at 9 AM",
    "tomorrow morning at 11 AM",
    "next Tuesday afternoon at 3 PM",
    "this Wednesday morning around 9 AM",
    "next Thursday afternoon, maybe 2 PM",
    "Friday morning at 10 AM if possible",
    "Wednesday afternoon at 1:30 PM",
    "Tuesday morning at 9:00 AM",
    "Thursday evening around 5 PM",
    "Monday morning, any time before noon",
    "Friday afternoon after 1 PM",
    "next week on a Tuesday or Wednesday",
    "sometime next week, late morning",
    "this coming Monday afternoon",
    "any morning this week except Friday",
    "next Friday afternoon, 2 PM"
]

DOCTOR_NAMES = [
    "Smith",
    "Johnson",
    "Williams",
    "Brown",
    "Jones",
    "Garcia",
    "Miller",
    "Davis",
    "Rodriguez",
    "Martinez",
    "Hernandez",
    "Lopez",
    "Gonzalez",
    "Wilson",
    "Anderson"
]

print(f"Loaded {len(MEDICAL_ISSUES)} medical issues")
print(f"Loaded {len(PATIENT_NAMES)} patient names")
print(f"Loaded {len(APPOINTMENT_TIMES)} appointment time options")
print(f"Loaded {len(DOCTOR_NAMES)} doctor names")
# Out:
# Loaded 15 medical issues
# Loaded 30 patient names
# Loaded 30 appointment time options
# Loaded 15 doctor names

# %%
def generate_transcript(issue, name, datetime, doctor, max_length=800, temperature=0.8):
    """
    Generate a single transcript of a phone call between doctors office and patient. The conversation should include reason for visiting doctors office, patient's name, preferred date/time, and doctor's name. Mark doctors office speaker with spk_0 and patient speaker with spk_1.

    Args:
        issue: Medical issue or reason for appointment
        name: Patient's name
        datetime: Preferred appointment date/time
        doctor: Doctor's name
        max_length: Maximum tokens to generate
        temperature: Sampling temperature (higher = more creative)

    Returns:
        Generated transcript text
    """
    prompt = PROMPT_TEMPLATE.format(
        issue=issue,
        name=name,
        datetime=datetime,
        doctor=doctor
    )

    inputs = tokenizer(prompt, return_tensors="pt", padding=True)
    if torch.cuda.is_available():
        inputs = {k: v.cuda() for k, v in inputs.items()}

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=max_length,
            temperature=temperature,
            do_sample=True,
            top_p=0.9,
            repetition_penalty=1.1,
            pad_token_id=tokenizer.pad_token_id,
            eos_token_id=tokenizer.eos_token_id
        )

    generated_text = tokenizer.decode(outputs[0])

    return generated_text

print("Transcript generation function ready.")
# Out:
# Transcript generation function ready.

# %%
issue = random.choice(MEDICAL_ISSUES)
name = random.choice(PATIENT_NAMES)
datetime = random.choice(APPOINTMENT_TIMES)
doctor = random.choice(DOCTOR_NAMES)

transcript = generate_transcript(issue, name, datetime, doctor)

print(transcript)
# Out:
# Generate a realistic phone conversation transcript between a doctor's office assistant (spk_0) and a patient (spk_1) calling to schedule an appointment.
# The conversation that you must generate must include reason for visiting doctors office, patient's name, preferred date/time, and doctor's name. Mark doctors office speaker with spk_0 and patient speaker with spk_1. Make sure that customer doesn't introduce himself first. First introduce yourself, then ask patient about their condition, than their name than doctor and then suggested date and time. Do not suggest doctors name, let patient tell themself who their doctor is. do not suggest time, always ask patient when they have time to visit. Do not check for time, just take suggestion from patient and tell tham that you wrote it down.
#
#
#
# Format each line as:
# spk_0: [assistant's dialogue]
# spk_1: [patient's dialogue]
#
# The conversation should include:
# 1. Greeting from the assistant
# 2. Patient describes their medical issue or reason for visit: allergic reaction symptoms
# 3. Patient provides their full name: Olivia Wilson
# 4. Discussion of preferred appointment date and time: next week on a Tuesday or Wednesday
# 5. Patient mentions their doctor: Dr. Johnson
# 6. Confirmation and polite closing
#
# Make it natural, focus only on facts, no repeating conditions or names no sympathising with patient
#
# Transcript:
# spk_0: Good morning! You've reached Green Valley Family Practice. How can I assist you today?
# spk_1: Hi there, I need to make an appointment because I'm having some allergic reactions lately.
# spk_0: I understand. May I have your full name, please?
# spk_1: It's Olivia Wilson.
# spk_0: Thank you, Ms. Wilson. Which doctor would you like to see?
# spk_1: I usually see Dr. Johnson.
# spk_0: Perfect, we'll arrange that for you. Do you have any preference for the date and time of your appointment?
# spk_1: Could we aim for next week? Maybe a Tuesday or Wednesday afternoon works best for me.
# spk_0: Alright, I've noted that down. We will get back to you shortly to confirm the exact timing. Is there anything else I can help you with?
# spk_1: No, that's all. Thanks for your help!
# spk_0: My pleasure, Ms. Wilson. Have a great day!
# <|im_end|>

# %%
# Create output directory
output_path = Path(OUTPUT_DIR)
output_path.mkdir(parents=True, exist_ok=True)
print(f"Output directory created: {output_path}")

# Generate transcripts
import random

transcripts = []
metadata = []

print(f"\nGenerating {NUM_TRANSCRIPTS} transcripts...\n")

for i in range(NUM_TRANSCRIPTS):
    # Randomly select parameters
    issue = random.choice(MEDICAL_ISSUES)
    name = random.choice(PATIENT_NAMES)
    datetime = random.choice(APPOINTMENT_TIMES)
    doctor = random.choice(DOCTOR_NAMES)

    print(f"[{i+1}/{NUM_TRANSCRIPTS}] Generating transcript for {name}...")
    print(f"  Issue: {issue}")
    print(f"  Doctor: Dr. {doctor}")
    print(f"  Time: {datetime}")

    try:
        transcript = generate_transcript(issue, name, datetime, doctor)

        # Save individual transcript file
        filename = f"transcript_{i+1:03d}.txt"
        filepath = output_path / filename
        filepath.write_text(transcript, encoding="utf-8")

        transcripts.append(transcript)
        metadata.append({
            "id": i + 1,
            "filename": filename,
            "patient_name": name,
            "doctor_name": f"Dr. {doctor}",
            "medical_issue": issue,
            "appointment_time": datetime
        })

        print(f"  ✓ Saved to {filename}")
        print()

    except Exception as e:
        print(f"  ✗ Error generating transcript: {e}")
        print()

print(f"\n{'='*60}")
print(f"Generation complete! Created {len(transcripts)} transcripts.")
print(f"{'='*60}")
# Out:
# Output directory created: /data/generated_transcripts
#
# Generating 100 transcripts...
#
# [1/100] Generating transcript for Kevin Patel...
#   Issue: back pain management
#   Doctor: Dr. Lopez
#   Time: next Tuesday afternoon at 3 PM
#   ✓ Saved to transcript_001.txt
#
# [2/100] Generating transcript for Isabella Carter...
#   Issue: digestive issues
#   Doctor: Dr. Brown
#   Time: next Tuesday at 1 PM
#   ✓ Saved to transcript_002.txt
#
# [3/100] Generating transcript for Michael Chen...
#   Issue: persistent cough and congestion
#   Doctor: Dr. Lopez
#   Time: this coming Monday afternoon
#   ✓ Saved to transcript_003.txt
#
# [4/100] Generating transcript for David Thompson...
#   Issue: follow-up for blood pressure monitoring
#   Doctor: Dr. Rodriguez
#   Time: next Wednesday at 2:30 PM
#   ✓ Saved to transcript_004.txt
#
# [5/100] Generating transcript for Daniel Kim...
#   Issue: persistent headaches for the past week
#   Doctor: Dr. Johnson
#   Time: this coming Monday afternoon
#   ✓ Saved to transcript_005.txt
#
# [6/100] Generating transcript for James Martinez...
#   Issue: routine diabetes check-up
#   Doctor: Dr. Jones
#   Time: Wednesday afternoon at 1:30 PM
#   ✓ Saved to transcript_006.txt
#
# [7/100] Generating transcript for Michael Chen...
#   Issue: sprained ankle evaluation
#   Doctor: Dr. Lopez
#   Time: end of this week, Friday around noon
#   ✓ Saved to transcript_007.txt
#
# [8/100] Generating transcript for Ava Wright...
#   Issue: knee pain after exercising
#   Doctor: Dr. Hernandez
#   Time: next Friday morning at 9 AM
#   ✓ Saved to transcript_008.txt
#
# [9/100] Generating transcript for Jennifer Taylor...
#   Issue: back pain management
#   Doctor: Dr. Brown
#   Time: tomorrow morning at 11 AM
#   ✓ Saved to transcript_009.txt
#
# [10/100] Generating transcript for Daniel Kim...
#   Issue: allergic reaction symptoms
#   Doctor: Dr. Rodriguez
#   Time: Friday afternoon after 1 PM
#   ✓ Saved to transcript_010.txt
#
# [11/100] Generating transcript for Robert Anderson...
#   Issue: digestive issues
#   Doctor: Dr. Brown
#   Time: sometime next week, late morning
#   ✓ Saved to transcript_011.txt
#
# [12/100] Generating transcript for Stephanie King...
#   Issue: medication refill and consultation
#   Doctor: Dr. Brown
#   Time: Wednesday afternoon at 1:30 PM
#   ✓ Saved to transcript_012.txt
#
# [13/100] Generating transcript for Jessica Williams...
#   Issue: follow-up for blood pressure monitoring
#   Doctor: Dr. Martinez
#   Time: Monday or Tuesday morning, before 10
#   ✓ Saved to transcript_013.txt
#
# [14/100] Generating transcript for David Thompson...
#   Issue: migraine consultation
#   Doctor: Dr. Gonzalez
#   Time: Friday morning at 10 AM if possible
#   ✓ Saved to transcript_014.txt
#
# [15/100] Generating transcript for Olivia Wilson...
#   Issue: migraine consultation
#   Doctor: Dr. Davis
#   Time: Friday afternoon after 1 PM
#   ✓ Saved to transcript_015.txt
#
# [16/100] Generating transcript for James Martinez...
#   Issue: knee pain after exercising
#   Doctor: Dr. Davis
#   Time: tomorrow morning at 11 AM
#   ✓ Saved to transcript_016.txt
#
# [17/100] Generating transcript for Michael Chen...
#   Issue: annual physical examination
#   Doctor: Dr. Smith
#   Time: early morning on Thursday, 8:30 AM
#   ✓ Saved to transcript_017.txt
#
# [18/100] Generating transcript for Robert Anderson...
#   Issue: annual physical examination
#   Doctor: Dr. Jones
#   Time: next Friday afternoon, 2 PM
#   ✓ Saved to transcript_018.txt
#
# [19/100] Generating transcript for Nicole Miller...
#   Issue: skin rash that won't go away
#   Doctor: Dr. Lopez
#   Time: next Thursday afternoon, maybe 2 PM
#   ✓ Saved to transcript_019.txt
#
# [20/100] Generating transcript for Liam Adams...
#   Issue: digestive issues
#   Doctor: Dr. Rodriguez
#   Time: sometime next week, late morning
#   ✓ Saved to transcript_020.txt
#
# [21/100] Generating transcript for James Martinez...
#   Issue: follow-up for blood pressure monitoring
#   Doctor: Dr. Jones
#   Time: next Friday afternoon, 2 PM
#   ✓ Saved to transcript_021.txt
#
# [22/100] Generating transcript for Sophia Hall...
#   Issue: discuss recent lab results
#   Doctor: Dr. Jones
#   Time: early next week, around 8 AM
#   ✓ Saved to transcript_022.txt
#
# [23/100] Generating transcript for Jessica Williams...
#   Issue: migraine consultation
#   Doctor: Dr. Johnson
#   Time: end of this week, Friday around noon
#   ✓ Saved to transcript_023.txt
#
# [24/100] Generating transcript for Brandon Scott...
#   Issue: back pain management
#   Doctor: Dr. Johnson
#   Time: this Thursday at 10:30 AM
#   ✓ Saved to transcript_024.txt
#
# [25/100] Generating transcript for Noah Baker...
#   Issue: annual physical examination
#   Doctor: Dr. Brown
#   Time: this coming Monday afternoon
#   ✓ Saved to transcript_025.txt
#
# [26/100] Generating transcript for Ethan Moore...
#   Issue: persistent cough and congestion
#   Doctor: Dr. Lopez
#   Time: this Friday afternoon, maybe 3 or 4 PM
#   ✓ Saved to transcript_026.txt
#
# [27/100] Generating transcript for David Thompson...
#   Issue: discuss recent lab results
#   Doctor: Dr. Anderson
#   Time: next week on a Tuesday or Wednesday
#   ✓ Saved to transcript_027.txt
#
# [28/100] Generating transcript for Mia Roberts...
#   Issue: sprained ankle evaluation
#   Doctor: Dr. Anderson
#   Time: early next week, around 8 AM
#   ✓ Saved to transcript_028.txt
#
# [29/100] Generating transcript for Isabella Carter...
#   Issue: medication refill and consultation
#   Doctor: Dr. Wilson
#   Time: this Thursday at 10:30 AM
#   ✓ Saved to transcript_029.txt
#
# [30/100] Generating transcript for Stephanie King...
#   Issue: knee pain after exercising
#   Doctor: Dr. Lopez
#   Time: tomorrow at 2 PM
#   ✓ Saved to transcript_030.txt
#
# [31/100] Generating transcript for Brandon Scott...
#   Issue: discuss recent lab results
#   Doctor: Dr. Martinez
#   Time: sometime next week, late morning
#   ✓ Saved to transcript_031.txt
#
# [32/100] Generating transcript for Daniel Kim...
#   Issue: migraine consultation
#   Doctor: Dr. Jones
#   Time: Wednesday afternoon at 1:30 PM
#   ✓ Saved to transcript_032.txt
#
# [33/100] Generating transcript for Ashley Garcia...
#   Issue: follow-up for blood pressure monitoring
#   Doctor: Dr. Davis
#   Time: this coming Monday afternoon
#   ✓ Saved to transcript_033.txt
#
# [34/100] Generating transcript for Ashley Garcia...
#   Issue: knee pain after exercising
#   Doctor: Dr. Brown
#   Time: next Friday afternoon, 2 PM
#   ✓ Saved to transcript_034.txt
#
# [35/100] Generating transcript for Alexander Phillips...
#   Issue: persistent headaches for the past week
#   Doctor: Dr. Martinez
#   Time: this Wednesday morning around 9 AM
#   ✓ Saved to transcript_035.txt
#
# [36/100] Generating transcript for James Martinez...
#   Issue: knee pain after exercising
#   Doctor: Dr. Rodriguez
#   Time: Wednesday afternoon at 1:30 PM
#   ✓ Saved to transcript_036.txt
#
# [37/100] Generating transcript for Alexander Phillips...
#   Issue: migraine consultation
#   Doctor: Dr. Rodriguez
#   Time: next Tuesday afternoon at 3 PM
#   ✓ Saved to transcript_037.txt
#
# [38/100] Generating transcript for Lisa Brown...
#   Issue: skin rash that won't go away
#   Doctor: Dr. Brown
#   Time: next week on a Tuesday or Wednesday
#   ✓ Saved to transcript_038.txt
#
# [39/100] Generating transcript for Isabella Carter...
#   Issue: routine diabetes check-up
#   Doctor: Dr. Garcia
#   Time: sometime next week, late morning
#   ✓ Saved to transcript_039.txt
#
# [40/100] Generating transcript for Christopher Lee...
#   Issue: routine diabetes check-up
#   Doctor: Dr. Garcia
#   Time: Thursday at 9:30 AM if possible
#   ✓ Saved to transcript_040.txt
#
# [41/100] Generating transcript for Robert Anderson...
#   Issue: discuss recent lab results
#   Doctor: Dr. Brown
#   Time: sometime next week, late morning
#   ✓ Saved to transcript_041.txt
#
# [42/100] Generating transcript for Sarah Johnson...
#   Issue: follow-up for blood pressure monitoring
#   Doctor: Dr. Martinez
#   Time: next Monday afternoon at 4 PM
#   ✓ Saved to transcript_042.txt
#
# [43/100] Generating transcript for Isabella Carter...
#   Issue: skin rash that won't go away
#   Doctor: Dr. Johnson
#   Time: this coming Monday afternoon
#   ✓ Saved to transcript_043.txt
#
# [44/100] Generating transcript for Sophia Hall...
#   Issue: follow-up for blood pressure monitoring
#   Doctor: Dr. Garcia
#   Time: next Friday morning at 9 AM
#   ✓ Saved to transcript_044.txt
#
# [45/100] Generating transcript for Amanda Davis...
#   Issue: flu-like symptoms
#   Doctor: Dr. Anderson
#   Time: next week, preferably Wednesday at 11 AM
#   ✓ Saved to transcript_045.txt
#
# [46/100] Generating transcript for Mason Evans...
#   Issue: medication refill and consultation
#   Doctor: Dr. Williams
#   Time: early morning on Thursday, 8:30 AM
#   ✓ Saved to transcript_046.txt
#
# [47/100] Generating transcript for Sarah Johnson...
#   Issue: discuss recent lab results
#   Doctor: Dr. Davis
#   Time: Tuesday morning at 9:00 AM
#   ✓ Saved to transcript_047.txt
#
# [48/100] Generating transcript for Noah Baker...
#   Issue: allergic reaction symptoms
#   Doctor: Dr. Hernandez
#   Time: early next week, around 8 AM
#   ✓ Saved to transcript_048.txt
#
# [49/100] Generating transcript for Noah Baker...
#   Issue: discuss recent lab results
#   Doctor: Dr. Davis
#   Time: next Friday morning at 9 AM
#   ✓ Saved to transcript_049.txt
#
# [50/100] Generating transcript for Stephanie King...
#   Issue: routine diabetes check-up
#   Doctor: Dr. Anderson
#   Time: sometime this week, afternoon would be best
#   ✓ Saved to transcript_050.txt
#
# [51/100] Generating transcript for Isabella Carter...
#   Issue: persistent cough and congestion
#   Doctor: Dr. Garcia
#   Time: Thursday at 9:30 AM if possible
#   ✓ Saved to transcript_051.txt
#
# [52/100] Generating transcript for Robert Anderson...
#   Issue: allergic reaction symptoms
#   Doctor: Dr. Wilson
#   Time: tomorrow at 2 PM
#   ✓ Saved to transcript_052.txt
#
# [53/100] Generating transcript for Jessica Williams...
#   Issue: routine diabetes check-up
#   Doctor: Dr. Brown
#   Time: Friday afternoon after 1 PM
#   ✓ Saved to transcript_053.txt
#
# [54/100] Generating transcript for Brandon Scott...
#   Issue: persistent cough and congestion
#   Doctor: Dr. Davis
#   Time: next Monday afternoon at 4 PM
#   ✓ Saved to transcript_054.txt
#
# [55/100] Generating transcript for Jessica Williams...
#   Issue: persistent cough and congestion
#   Doctor: Dr. Johnson
#   Time: any morning this week except Friday
#   ✓ Saved to transcript_055.txt
#
# [56/100] Generating transcript for Ashley Garcia...
#   Issue: annual physical examination
#   Doctor: Dr. Martinez
#   Time: any morning this week except Friday
#   ✓ Saved to transcript_056.txt
#
# [57/100] Generating transcript for Ashley Garcia...
#   Issue: back pain management
#   Doctor: Dr. Williams
#   Time: next Friday morning at 9 AM
#   ✓ Saved to transcript_057.txt
#
# [58/100] Generating transcript for Eric Green...
#   Issue: persistent cough and congestion
#   Doctor: Dr. Garcia
#   Time: next Monday afternoon at 4 PM
#   ✓ Saved to transcript_058.txt
#
# [59/100] Generating transcript for Brandon Scott...
#   Issue: annual physical examination
#   Doctor: Dr. Martinez
#   Time: Thursday at 9:30 AM if possible
#   ✓ Saved to transcript_059.txt
#
# [60/100] Generating transcript for Daniel Kim...
#   Issue: allergic reaction symptoms
#   Doctor: Dr. Rodriguez
#   Time: next Thursday afternoon, maybe 2 PM
#   ✓ Saved to transcript_060.txt
#
# [61/100] Generating transcript for Ashley Garcia...
#   Issue: allergic reaction symptoms
#   Doctor: Dr. Wilson
#   Time: early next week, around 8 AM
#   ✓ Saved to transcript_061.txt
#
# [62/100] Generating transcript for Michelle White...
#   Issue: migraine consultation
#   Doctor: Dr. Jones
#   Time: next Tuesday afternoon at 3 PM
#   ✓ Saved to transcript_062.txt
#
# [63/100] Generating transcript for Robert Anderson...
#   Issue: follow-up for blood pressure monitoring
#   Doctor: Dr. Brown
#   Time: Monday morning, any time before noon
#   ✓ Saved to transcript_063.txt
#
# [64/100] Generating transcript for Ava Wright...
#   Issue: skin rash that won't go away
#   Doctor: Dr. Miller
#   Time: any morning this week except Friday
#   ✓ Saved to transcript_064.txt
#
# [65/100] Generating transcript for Isabella Carter...
#   Issue: allergic reaction symptoms
#   Doctor: Dr. Miller
#   Time: next week on a Tuesday or Wednesday
#   ✓ Saved to transcript_065.txt
#
# [66/100] Generating transcript for James Martinez...
#   Issue: knee pain after exercising
#   Doctor: Dr. Davis
#   Time: next Thursday afternoon, maybe 2 PM
#   ✓ Saved to transcript_066.txt
#
# [67/100] Generating transcript for Stephanie King...
#   Issue: routine diabetes check-up
#   Doctor: Dr. Wilson
#   Time: sometime next week, late morning
#   ✓ Saved to transcript_067.txt
#
# [68/100] Generating transcript for Noah Baker...
#   Issue: discuss recent lab results
#   Doctor: Dr. Rodriguez
#   Time: next Tuesday afternoon at 3 PM
#   ✓ Saved to transcript_068.txt
#
# [69/100] Generating transcript for Ethan Moore...
#   Issue: flu-like symptoms
#   Doctor: Dr. Hernandez
#   Time: Thursday at 9:30 AM if possible
#   ✓ Saved to transcript_069.txt
#
# [70/100] Generating transcript for Ashley Garcia...
#   Issue: flu-like symptoms
#   Doctor: Dr. Davis
#   Time: next Tuesday afternoon at 3 PM
#   ✓ Saved to transcript_070.txt
#
# [71/100] Generating transcript for Jennifer Taylor...
#   Issue: flu-like symptoms
#   Doctor: Dr. Brown
#   Time: Thursday evening around 5 PM
#   ✓ Saved to transcript_071.txt
#
# [72/100] Generating transcript for David Thompson...
#   Issue: back pain management
#   Doctor: Dr. Garcia
#   Time: Friday morning at 10 AM if possible
#   ✓ Saved to transcript_072.txt
#
# [73/100] Generating transcript for Daniel Kim...
#   Issue: sprained ankle evaluation
#   Doctor: Dr. Smith
#   Time: Thursday at 9:30 AM if possible
#   ✓ Saved to transcript_073.txt
#
# [74/100] Generating transcript for Sophia Hall...
#   Issue: allergic reaction symptoms
#   Doctor: Dr. Martinez
#   Time: next week, preferably Wednesday at 11 AM
#   ✓ Saved to transcript_074.txt
#
# [75/100] Generating transcript for Robert Anderson...
#   Issue: discuss recent lab results
#   Doctor: Dr. Rodriguez
#   Time: next Tuesday afternoon at 3 PM
#   ✓ Saved to transcript_075.txt
#
# [76/100] Generating transcript for Brian Adams...
#   Issue: routine diabetes check-up
#   Doctor: Dr. Smith
#   Time: end of this week, Friday around noon
#   ✓ Saved to transcript_076.txt
#
# [77/100] Generating transcript for Nicole Miller...
#   Issue: discuss recent lab results
#   Doctor: Dr. Rodriguez
#   Time: next Friday morning at 9 AM
#   ✓ Saved to transcript_077.txt
#
# [78/100] Generating transcript for Nicole Miller...
#   Issue: back pain management
#   Doctor: Dr. Garcia
#   Time: next week on a Tuesday or Wednesday
#   ✓ Saved to transcript_078.txt
#
# [79/100] Generating transcript for James Martinez...
#   Issue: annual physical examination
#   Doctor: Dr. Lopez
#   Time: next Monday afternoon at 4 PM
#   ✓ Saved to transcript_079.txt
#
# [80/100] Generating transcript for Lisa Brown...
#   Issue: migraine consultation
#   Doctor: Dr. Davis
#   Time: tomorrow morning at 11 AM
#   ✓ Saved to transcript_080.txt
#
# [81/100] Generating transcript for Isabella Carter...
#   Issue: discuss recent lab results
#   Doctor: Dr. Martinez
#   Time: early morning on Thursday, 8:30 AM
#   ✓ Saved to transcript_081.txt
#
# [82/100] Generating transcript for Mia Roberts...
#   Issue: annual physical examination
#   Doctor: Dr. Brown
#   Time: Friday afternoon after 1 PM
#   ✓ Saved to transcript_082.txt
#
# [83/100] Generating transcript for Amanda Davis...
#   Issue: routine diabetes check-up
#   Doctor: Dr. Martinez
#   Time: Monday morning, any time before noon
#   ✓ Saved to transcript_083.txt
#
# [84/100] Generating transcript for Jennifer Taylor...
#   Issue: annual physical examination
#   Doctor: Dr. Brown
#   Time: next Friday afternoon, 2 PM
#   ✓ Saved to transcript_084.txt
#
# [85/100] Generating transcript for Robert Anderson...
#   Issue: back pain management
#   Doctor: Dr. Garcia
#   Time: this Wednesday morning around 9 AM
#   ✓ Saved to transcript_085.txt
#
# [86/100] Generating transcript for Robert Anderson...
#   Issue: skin rash that won't go away
#   Doctor: Dr. Wilson
#   Time: Wednesday afternoon at 1:30 PM
#   ✓ Saved to transcript_086.txt
#
# [87/100] Generating transcript for Noah Baker...
#   Issue: persistent headaches for the past week
#   Doctor: Dr. Garcia
#   Time: this Thursday at 10:30 AM
#   ✓ Saved to transcript_087.txt
#
# [88/100] Generating transcript for Noah Baker...
#   Issue: skin rash that won't go away
#   Doctor: Dr. Martinez
#   Time: Thursday evening around 5 PM
#   ✓ Saved to transcript_088.txt
#
# [89/100] Generating transcript for Jessica Williams...
#   Issue: routine diabetes check-up
#   Doctor: Dr. Gonzalez
#   Time: early next week, around 8 AM
#   ✓ Saved to transcript_089.txt
#
# [90/100] Generating transcript for Jennifer Taylor...
#   Issue: routine diabetes check-up
#   Doctor: Dr. Miller
#   Time: Thursday at 9:30 AM if possible
#   ✓ Saved to transcript_090.txt
#
# [91/100] Generating transcript for Christopher Lee...
#   Issue: back pain management
#   Doctor: Dr. Williams
#   Time: Friday afternoon after 1 PM
#   ✓ Saved to transcript_091.txt
#
# [92/100] Generating transcript for Amanda Davis...
#   Issue: skin rash that won't go away
#   Doctor: Dr. Hernandez
#   Time: next Friday morning at 9 AM
#   ✓ Saved to transcript_092.txt
#
# [93/100] Generating transcript for James Martinez...
#   Issue: annual physical examination
#   Doctor: Dr. Miller
#   Time: this coming Monday afternoon
#   ✓ Saved to transcript_093.txt
#
# [94/100] Generating transcript for Eric Green...
#   Issue: persistent cough and congestion
#   Doctor: Dr. Jones
#   Time: this Friday afternoon, maybe 3 or 4 PM
#   ✓ Saved to transcript_094.txt
#
# [95/100] Generating transcript for Brandon Scott...
#   Issue: annual physical examination
#   Doctor: Dr. Brown
#   Time: next Monday afternoon at 4 PM
#   ✓ Saved to transcript_095.txt
#
# [96/100] Generating transcript for Alexander Phillips...
#   Issue: sprained ankle evaluation
#   Doctor: Dr. Johnson
#   Time: tomorrow morning at 11 AM
#   ✓ Saved to transcript_096.txt
#
# [97/100] Generating transcript for Mason Evans...
#   Issue: knee pain after exercising
#   Doctor: Dr. Davis
#   Time: next Friday morning at 9 AM
#   ✓ Saved to transcript_097.txt
#
# [98/100] Generating transcript for Jennifer Taylor...
#   Issue: allergic reaction symptoms
#   Doctor: Dr. Brown
#   Time: Tuesday morning at 9:00 AM
#   ✓ Saved to transcript_098.txt
#
# [99/100] Generating transcript for Lisa Brown...
#   Issue: knee pain after exercising
#   Doctor: Dr. Smith
#   Time: this Wednesday morning around 9 AM
#   ✓ Saved to transcript_099.txt
#
# [100/100] Generating transcript for Robert Anderson...
#   Issue: knee pain after exercising
#   Doctor: Dr. Brown
#   Time: tomorrow at 2 PM
#   ✓ Saved to transcript_100.txt
#
#
# ============================================================
# Generation complete! Created 100 transcripts.
# ============================================================

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Save metadata as JSON
metadata_file = output_path / "metadata.json"
metadata_file.write_text(json.dumps(metadata, indent=2, ensure_ascii=False), encoding="utf-8")
print(f"Metadata saved to {metadata_file}")

# Display first transcript as example
if transcripts:
    print("\n" + "="*60)
    print("EXAMPLE TRANSCRIPT (First Generated):")
    print("="*60)
    print(transcripts[0])
    print("="*60)
# Out:
# Metadata saved to /data/generated_transcripts/metadata.json
#
# ============================================================
# EXAMPLE TRANSCRIPT (First Generated):
# ============================================================
# Generate a realistic phone conversation transcript between a doctor's office assistant (spk_0) and a patient (spk_1) calling to schedule an appointment.
# The conversation that you must generate must include reason for visiting doctors office, patient's name, preferred date/time, and doctor's name. Mark doctors office speaker with spk_0 and patient speaker with spk_1. Make sure that customer doesn't introduce himself first. First introduce yourself, then ask patient about their condition, than their name than doctor and then suggested date and time. Do not suggest doctors name, let patient tell themself who their doctor is. do not suggest time, always ask patient when they have time to visit. Do not check for time, just take suggestion from patient and tell tham that you wrote it down.
#
#
#
# Format each line as:
# spk_0: [assistant's dialogue]
# spk_1: [patient's dialogue]
#
# The conversation should include:
# 1. Greeting from the assistant
# 2. Patient describes their medical issue or reason for visit: back pain management
# 3. Patient provides their full name: Kevin Patel
# 4. Discussion of preferred appointment date and time: next Tuesday afternoon at 3 PM
# 5. Patient mentions their doctor: Dr. Lopez
# 6. Confirmation and polite closing
#
# Make it natural, focus only on facts, no repeating conditions or names no sympathising with patient
#
# Transcript:
# <|im_end|>
# ============================================================

# %%
# Summary statistics
print("\n📊 GENERATION SUMMARY")
print("="*60)
print(f"Total transcripts generated: {len(transcripts)}")
print(f"Output directory: {output_path}")
print(f"\nFiles created:")
for meta in metadata:
    print(f"  - {meta['filename']}: {meta['patient_name']} → Dr. {meta['doctor_name'].replace('Dr. ', '')}")
print(f"  - metadata.json")
print("="*60)
print("\n✅ All transcripts ready for use!")
# Out:
# 📊 GENERATION SUMMARY
# ============================================================
# Total transcripts generated: 100
# Output directory: /data/generated_transcripts
#
# Files created:
#   - transcript_001.txt: Kevin Patel → Dr. Lopez
#   - transcript_002.txt: Isabella Carter → Dr. Brown
#   - transcript_003.txt: Michael Chen → Dr. Lopez
#   - transcript_004.txt: David Thompson → Dr. Rodriguez
#   - transcript_005.txt: Daniel Kim → Dr. Johnson
#   - transcript_006.txt: James Martinez → Dr. Jones
#   - transcript_007.txt: Michael Chen → Dr. Lopez
#   - transcript_008.txt: Ava Wright → Dr. Hernandez
#   - transcript_009.txt: Jennifer Taylor → Dr. Brown
#   - transcript_010.txt: Daniel Kim → Dr. Rodriguez
#   - transcript_011.txt: Robert Anderson → Dr. Brown
#   - transcript_012.txt: Stephanie King → Dr. Brown
#   - transcript_013.txt: Jessica Williams → Dr. Martinez
#   - transcript_014.txt: David Thompson → Dr. Gonzalez
#   - transcript_015.txt: Olivia Wilson → Dr. Davis
#   - transcript_016.txt: James Martinez → Dr. Davis
#   - transcript_017.txt: Michael Chen → Dr. Smith
#   - transcript_018.txt: Robert Anderson → Dr. Jones
#   - transcript_019.txt: Nicole Miller → Dr. Lopez
#   - transcript_020.txt: Liam Adams → Dr. Rodriguez
#   - transcript_021.txt: James Martinez → Dr. Jones
#   - transcript_022.txt: Sophia Hall → Dr. Jones
#   - transcript_023.txt: Jessica Williams → Dr. Johnson
#   - transcript_024.txt: Brandon Scott → Dr. Johnson
#   - transcript_025.txt: Noah Baker → Dr. Brown
#   - transcript_026.txt: Ethan Moore → Dr. Lopez
#   - transcript_027.txt: David Thompson → Dr. Anderson
#   - transcript_028.txt: Mia Roberts → Dr. Anderson
#   - transcript_029.txt: Isabella Carter → Dr. Wilson
#   - transcript_030.txt: Stephanie King → Dr. Lopez
#   - transcript_031.txt: Brandon Scott → Dr. Martinez
#   - transcript_032.txt: Daniel Kim → Dr. Jones
#   - transcript_033.txt: Ashley Garcia → Dr. Davis
#   - transcript_034.txt: Ashley Garcia → Dr. Brown
#   - transcript_035.txt: Alexander Phillips → Dr. Martinez
#   - transcript_036.txt: James Martinez → Dr. Rodriguez
#   - transcript_037.txt: Alexander Phillips → Dr. Rodriguez
#   - transcript_038.txt: Lisa Brown → Dr. Brown
#   - transcript_039.txt: Isabella Carter → Dr. Garcia
#   - transcript_040.txt: Christopher Lee → Dr. Garcia
#   - transcript_041.txt: Robert Anderson → Dr. Brown
#   - transcript_042.txt: Sarah Johnson → Dr. Martinez
#   - transcript_043.txt: Isabella Carter → Dr. Johnson
#   - transcript_044.txt: Sophia Hall → Dr. Garcia
#   - transcript_045.txt: Amanda Davis → Dr. Anderson
#   - transcript_046.txt: Mason Evans → Dr. Williams
#   - transcript_047.txt: Sarah Johnson → Dr. Davis
#   - transcript_048.txt: Noah Baker → Dr. Hernandez
#   - transcript_049.txt: Noah Baker → Dr. Davis
#   - transcript_050.txt: Stephanie King → Dr. Anderson
#   - transcript_051.txt: Isabella Carter → Dr. Garcia
#   - transcript_052.txt: Robert Anderson → Dr. Wilson
#   - transcript_053.txt: Jessica Williams → Dr. Brown
#   - transcript_054.txt: Brandon Scott → Dr. Davis
#   - transcript_055.txt: Jessica Williams → Dr. Johnson
#   - transcript_056.txt: Ashley Garcia → Dr. Martinez
#   - transcript_057.txt: Ashley Garcia → Dr. Williams
#   - transcript_058.txt: Eric Green → Dr. Garcia
#   - transcript_059.txt: Brandon Scott → Dr. Martinez
#   - transcript_060.txt: Daniel Kim → Dr. Rodriguez
#   - transcript_061.txt: Ashley Garcia → Dr. Wilson
#   - transcript_062.txt: Michelle White → Dr. Jones
#   - transcript_063.txt: Robert Anderson → Dr. Brown
#   - transcript_064.txt: Ava Wright → Dr. Miller
#   - transcript_065.txt: Isabella Carter → Dr. Miller
#   - transcript_066.txt: James Martinez → Dr. Davis
#   - transcript_067.txt: Stephanie King → Dr. Wilson
#   - transcript_068.txt: Noah Baker → Dr. Rodriguez
#   - transcript_069.txt: Ethan Moore → Dr. Hernandez
#   - transcript_070.txt: Ashley Garcia → Dr. Davis
#   - transcript_071.txt: Jennifer Taylor → Dr. Brown
#   - transcript_072.txt: David Thompson → Dr. Garcia
#   - transcript_073.txt: Daniel Kim → Dr. Smith
#   - transcript_074.txt: Sophia Hall → Dr. Martinez
#   - transcript_075.txt: Robert Anderson → Dr. Rodriguez
#   - transcript_076.txt: Brian Adams → Dr. Smith
#   - transcript_077.txt: Nicole Miller → Dr. Rodriguez
#   - transcript_078.txt: Nicole Miller → Dr. Garcia
#   - transcript_079.txt: James Martinez → Dr. Lopez
#   - transcript_080.txt: Lisa Brown → Dr. Davis
#   - transcript_081.txt: Isabella Carter → Dr. Martinez
#   - transcript_082.txt: Mia Roberts → Dr. Brown
#   - transcript_083.txt: Amanda Davis → Dr. Martinez
#   - transcript_084.txt: Jennifer Taylor → Dr. Brown
#   - transcript_085.txt: Robert Anderson → Dr. Garcia
#   - transcript_086.txt: Robert Anderson → Dr. Wilson
#   - transcript_087.txt: Noah Baker → Dr. Garcia
#   - transcript_088.txt: Noah Baker → Dr. Martinez
#   - transcript_089.txt: Jessica Williams → Dr. Gonzalez
#   - transcript_090.txt: Jennifer Taylor → Dr. Miller
#   - transcript_091.txt: Christopher Lee → Dr. Williams
#   - transcript_092.txt: Amanda Davis → Dr. Hernandez
#   - transcript_093.txt: James Martinez → Dr. Miller
#   - transcript_094.txt: Eric Green → Dr. Jones
#   - transcript_095.txt: Brandon Scott → Dr. Brown
#   - transcript_096.txt: Alexander Phillips → Dr. Johnson
#   - transcript_097.txt: Mason Evans → Dr. Davis
#   - transcript_098.txt: Jennifer Taylor → Dr. Brown
#   - transcript_099.txt: Lisa Brown → Dr. Smith
#   - transcript_100.txt: Robert Anderson → Dr. Brown
#   - metadata.json
# ============================================================
#
# ✅ All transcripts ready for use!

# %%
# !zip -r /data/generated_transcripts.zip /data/generated_transcripts/
from google.colab import files
files.download("/data/generated_transcripts.zip")
# Out:
#   adding: data/generated_transcripts/ (stored 0%)
#   adding: data/generated_transcripts/transcript_048.txt (deflated 51%)
#   adding: data/generated_transcripts/transcript_060.txt (deflated 55%)
#   adding: data/generated_transcripts/transcript_019.txt (deflated 63%)
#   adding: data/generated_transcripts/transcript_090.txt (deflated 55%)
#   adding: data/generated_transcripts/transcript_007.txt (deflated 55%)
#   adding: data/generated_transcripts/transcript_094.txt (deflated 51%)
#   adding: data/generated_transcripts/transcript_025.txt (deflated 62%)
#   adding: data/generated_transcripts/transcript_050.txt (deflated 58%)
#   adding: data/generated_transcripts/transcript_059.txt (deflated 58%)
#   adding: data/generated_transcripts/transcript_088.txt (deflated 51%)
#   adding: data/generated_transcripts/transcript_029.txt (deflated 51%)
#   adding: data/generated_transcripts/transcript_037.txt (deflated 64%)
#   adding: data/generated_transcripts/transcript_089.txt (deflated 64%)
#   adding: data/generated_transcripts/transcript_043.txt (deflated 61%)
#   adding: data/generated_transcripts/transcript_078.txt (deflated 53%)
#   adding: data/generated_transcripts/transcript_095.txt (deflated 60%)
#   adding: data/generated_transcripts/transcript_062.txt (deflated 56%)
#   adding: data/generated_transcripts/transcript_004.txt (deflated 54%)
#   adding: data/generated_transcripts/transcript_036.txt (deflated 56%)
#   adding: data/generated_transcripts/transcript_076.txt (deflated 56%)
#   adding: data/generated_transcripts/transcript_075.txt (deflated 53%)
#   adding: data/generated_transcripts/transcript_056.txt (deflated 57%)
#   adding: data/generated_transcripts/transcript_057.txt (deflated 62%)
#   adding: data/generated_transcripts/transcript_016.txt (deflated 51%)
#   adding: data/generated_transcripts/transcript_021.txt (deflated 54%)
#   adding: data/generated_transcripts/transcript_024.txt (deflated 56%)
#   adding: data/generated_transcripts/transcript_005.txt (deflated 63%)
#   adding: data/generated_transcripts/transcript_014.txt (deflated 55%)
#   adding: data/generated_transcripts/transcript_069.txt (deflated 56%)
#   adding: data/generated_transcripts/transcript_086.txt (deflated 51%)
#   adding: data/generated_transcripts/transcript_046.txt (deflated 51%)
#   adding: data/generated_transcripts/transcript_006.txt (deflated 51%)
#   adding: data/generated_transcripts/transcript_052.txt (deflated 64%)
#   adding: data/generated_transcripts/transcript_065.txt (deflated 57%)
#   adding: data/generated_transcripts/metadata.json (deflated 90%)
#   adding: data/generated_transcripts/transcript_068.txt (deflated 51%)
#   adding: data/generated_transcripts/transcript_063.txt (deflated 63%)
#   adding: data/generated_transcripts/transcript_026.txt (deflated 65%)
#   adding: data/generated_transcripts/transcript_072.txt (deflated 51%)
#   adding: data/generated_transcripts/transcript_071.txt (deflated 63%)
#   adding: data/generated_transcripts/transcript_003.txt (deflated 58%)
#   adding: data/generated_transcripts/transcript_013.txt (deflated 55%)
#   adding: data/generated_transcripts/transcript_009.txt (deflated 60%)
#   adding: data/generated_transcripts/transcript_027.txt (deflated 54%)
#   adding: data/generated_transcripts/transcript_044.txt (deflated 61%)
#   adding: data/generated_transcripts/transcript_030.txt (deflated 52%)
#   adding: data/generated_transcripts/transcript_082.txt (deflated 58%)
#   adding: data/generated_transcripts/transcript_039.txt (deflated 53%)
#   adding: data/generated_transcripts/transcript_002.txt (deflated 55%)
#   adding: data/generated_transcripts/transcript_080.txt (deflated 52%)
#   adding: data/generated_transcripts/transcript_034.txt (deflated 56%)
#   adding: data/generated_transcripts/transcript_054.txt (deflated 56%)
#   adding: data/generated_transcripts/transcript_032.txt (deflated 51%)
#   adding: data/generated_transcripts/transcript_098.txt (deflated 57%)
#   adding: data/generated_transcripts/transcript_012.txt (deflated 53%)
#   adding: data/generated_transcripts/transcript_096.txt (deflated 51%)
#   adding: data/generated_transcripts/transcript_097.txt (deflated 55%)
#   adding: data/generated_transcripts/transcript_035.txt (deflated 55%)
#   adding: data/generated_transcripts/transcript_081.txt (deflated 63%)
#   adding: data/generated_transcripts/transcript_015.txt (deflated 56%)
#   adding: data/generated_transcripts/transcript_084.txt (deflated 61%)
#   adding: data/generated_transcripts/transcript_100.txt (deflated 59%)
#   adding: data/generated_transcripts/transcript_031.txt (deflated 62%)
#   adding: data/generated_transcripts/transcript_011.txt (deflated 52%)
#   adding: data/generated_transcripts/transcript_067.txt (deflated 56%)
#   adding: data/generated_transcripts/transcript_018.txt (deflated 51%)
#   adding: data/generated_transcripts/transcript_087.txt (deflated 54%)
#   adding: data/generated_transcripts/transcript_010.txt (deflated 55%)
#   adding: data/generated_transcripts/transcript_047.txt (deflated 65%)
#   adding: data/generated_transcripts/transcript_066.txt (deflated 63%)
#   adding: data/generated_transcripts/transcript_073.txt (deflated 53%)
#   adding: data/generated_transcripts/transcript_077.txt (deflated 64%)
#   adding: data/generated_transcripts/transcript_074.txt (deflated 54%)
#   adding: data/generated_transcripts/transcript_079.txt (deflated 63%)
#   adding: data/generated_transcripts/transcript_049.txt (deflated 63%)
#   adding: data/generated_transcripts/transcript_091.txt (deflated 56%)
#   adding: data/generated_transcripts/transcript_092.txt (deflated 53%)
#   adding: data/generated_transcripts/transcript_061.txt (deflated 56%)
#   adding: data/generated_transcripts/transcript_038.txt (deflated 55%)
#   adding: data/generated_transcripts/transcript_099.txt (deflated 54%)
#   adding: data/generated_transcripts/transcript_040.txt (deflated 51%)
#   adding: data/generated_transcripts/transcript_085.txt (deflated 62%)
#   adding: data/generated_transcripts/transcript_064.txt (deflated 62%)
#   adding: data/generated_transcripts/transcript_053.txt (deflated 55%)
#   adding: data/generated_transcripts/transcript_083.txt (deflated 53%)
#   adding: data/generated_transcripts/transcript_001.txt (deflated 51%)
#   adding: data/generated_transcripts/transcript_033.txt (deflated 56%)
#   adding: data/generated_transcripts/transcript_008.txt (deflated 51%)
#   adding: data/generated_transcripts/transcript_042.txt (deflated 65%)
#   adding: data/generated_transcripts/transcript_023.txt (deflated 58%)
#   adding: data/generated_transcripts/transcript_045.txt (deflated 51%)
#   adding: data/generated_transcripts/transcript_020.txt (deflated 56%)
#   adding: data/generated_transcripts/transcript_041.txt (deflated 64%)
#   adding: data/generated_transcripts/transcript_070.txt (deflated 53%)
#   adding: data/generated_transcripts/transcript_017.txt (deflated 57%)
#   adding: data/generated_transcripts/transcript_022.txt (deflated 55%)
#   adding: data/generated_transcripts/transcript_051.txt (deflated 55%)
#   adding: data/generated_transcripts/transcript_093.txt (deflated 51%)
#   adding: data/generated_transcripts/transcript_058.txt (deflated 55%)
#   adding: data/generated_transcripts/transcript_055.txt (deflated 65%)
#   adding: data/generated_transcripts/transcript_028.txt (deflated 55%)

# %% [markdown]
# ## Next Steps
#
# The generated transcripts are now saved in the output directory. Each transcript:
# - Is saved as a separate `.txt` file
# - Follows the format with `spk_0` (assistant) and `spk_1` (patient)
# - Contains realistic conversation flow
#
# **To generate more transcripts:**
# 1. Change the `NUM_TRANSCRIPTS` variable in the configuration cell
# 2. Re-run the generation cells
#
# **To customize:**
# - Add more medical issues, names, or appointment times to the sample data
# - Adjust the `temperature` parameter in the generation function for more/less creative outputs
# - Modify the prompt template to change conversation structure
#
# **Integration with the rewriter notebook:**
# - Point the `ROOT_DIR` in the rewriter notebook to `OUTPUT_DIR` from this notebook
# - The rewriter will extract `spk_1` lines and convert them to email format
